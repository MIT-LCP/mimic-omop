# %% [markdown]
# # Extract section headers for discharge summaries
#
# This notebook investigates and tries to harmonize section headers for discharge summaries.

# %%
import pandas as pd
import numpy as np
import os
import re
import psycopg2
from IPython.display import display, HTML

# %% [markdown]
# Connect to the database.

# %%
# specify user/password/where the database is
sqluser = 'postgres'
sqlpass = 'postgres'
dbname = 'mimic'
schema_name = 'mimiciii'
host = 'localhost'

query_schema = 'SET search_path to ' + schema_name + ';'

# connect to the database
con = psycopg2.connect(dbname=dbname, user=sqluser, password=sqlpass, host=host)

# %%
# load a single note
query = query_schema + """
select * from noteevents
where category = 'Discharge summary'
"""
df = pd.read_sql_query(query, con)
df.columns
# Out:
# Index(['row_id', 'subject_id', 'hadm_id', 'chartdate', 'charttime',
#        'storetime', 'category', 'description', 'cgid', 'iserror', 'text'],
#       dtype='object')

# %%
# read the map
smap = pd.read_csv('section-header-mapping.csv', header=0)
smap.columns = ['header','header_fixed']
smap = smap.set_index('header')['header_fixed'].to_dict()

# %%
# find section headers - outputs a list of matches
pattern = "\n[ ]*\n([A-z0-9 ]+)(:| WERE | INCLUD | IS | ARE)"

# summarize each section header found in the notes 
note_list = list()

# how many times it is preceeded by a blank line
# how many times it is all capital letters
# how many times it spans more than 1 line

def cleanup_header_name(header_name):
    # normalize header name: remove preceeding/trailing whitespace, convert to lower case
    return header_name.lstrip(' ').rstrip(' ').lower()

for i, row in df.iterrows():
    if row['description']=='Addendum':
        continue
    row_id = row['row_id']
    text = row['text']
    hadm_id = row['hadm_id']
    
    # remove bad matches
    match_list = list()
    for match in re.finditer(pattern, text, re.M):
        header_name = cleanup_header_name(match.groups()[0])
        if header_name in ('disp'):
            # not a true section header
            continue
        else:
            match_list.append(match)
    
    current_note_list = list()
    prev_match = None
    
    for match in match_list:
        header_name = cleanup_header_name(match.groups()[0])
        # initialize dictionary of meta-data for this section
        section_info_dict = {'first_match': False,
                             'blank_section': False,
                             'multiline_section': False,
                             'blank_line_preceeds': False,
                             'row_id': row_id,
                             'hadm_id': hadm_id,
                             'header': header_name,
                             'header_fixed': smap[header_name]}
                    
        if prev_match is not None:
            # checks that require the previous match object
            prev_section = text[prev_match.end():match.start()]

            # is the previous section blank
            if prev_section.replace('\n','').replace(' ','') == '':
                current_note_list[-1]['blank_section'] = True

            # does the previous section span more than 1 line (excluding the last, possibly new-line, character)
            if '\n' in prev_section[0:-1]:
                current_note_list[-1]['multiline_section'] = True

            # how many times it is preceeded by a blank line
            if text[match.start()-1] == '\n':
                section_info_dict['blank_line_preceeds'] = True
        else:
            section_info_dict['first_match'] = True

        prev_match = match
        current_note_list.append(section_info_dict)

    note_list.extend(current_note_list)
    
# info from section headers
sh = pd.DataFrame(note_list)

# %%
# total number of discharge summaries
N = (df['description']=='Report').sum()

grp = sh.groupby('header_fixed').sum()
grp.drop(['row_id','hadm_id'], axis=1, inplace=True)
grp = grp.merge(sh.groupby('header_fixed')[['row_id']].count(), how='left', left_index=True, right_index=True)
grp['percentage'] = grp['row_id']/N*100.0

#grp.sort_values('row_id', ascending=False).reset_index()[['header','header']].to_csv('section-header-mapping.csv', index=False)

grp.sort_values('row_id', ascending=False)
# Out:
#                                                     blank_line_preceeds  \
# header_fixed
# service                                                            35.0
# past medical history                                            20501.0
# history of present illness                                      24501.0
# hospital course                                                 20744.0
# admission medications                                           14556.0
# allergies                                                         296.0
# discharge condition                                             31424.0
# discharge disposition                                           32735.0
# physical examination                                             9004.0
# date of birth                                                       2.0
# discharge medications                                           16466.0
# social history                                                  19055.0
# discharge diagnosis                                               114.0
# family history                                                  18885.0
# discharge instructions                                          28244.0
# attending                                                           3.0
# major surgical or invasive procedure                             3681.0
# pertinent results                                               20382.0
# followup instructions                                            8837.0
# facility                                                            0.0
# completed by                                                    16028.0
# dictated by                                                       538.0
# impression                                                        202.0
# discharge diagnoses                                               402.0
# department                                                         46.0
# findings                                                           97.0
# laboratory data                                                    17.0
# review of systems                                                  57.0
# provider                                                           34.0
# neurologic                                                         40.0
# ...                                                                 ...
# micu admission vitals                                               0.0
# ct abdomen before and after iv contrast                             0.0
# micu course by problem list                                         0.0
# ct abd with iv and oral contrast                                    0.0
# micu course notable for the following                               0.0
# micu events                                                         0.0
# micu events significant for                                         0.0
# micu hpi                                                            0.0
# micu imaging                                                        0.0
# micu labs                                                           0.0
# micu medications                                                    0.0
# micu addend                                                         0.0
# ct abdomen upon admission read the following                        0.0
# microscopic hematuria                                               0.0
# ct and ctp of head                                                  0.0
# microbiology at osh summary                                         0.0
# ct and mris                                                         0.0
# microbiology info                                                   0.0
# microbiology labs                                                   0.0
# microbiology on this admission                                      0.0
# microbiology overview                                               0.0
# ct airways                                                          0.0
# microscopic                                                         0.0
# microbiology revealed the following                                 0.0
# microbiology review                                                 0.0
# ct abm                                                              0.0
# microbiololgy                                                       0.0
# microcalcifications                                                 0.0
# ct abdomen with iv contrast and with limited or...                  0.0
# zinc sulfate  220 mg capsule  sig                                   0.0
#
#                                                     blank_section  \
# header_fixed
# service                                                    2872.0
# past medical history                                         30.0
# history of present illness                                   21.0
# hospital course                                              53.0
# admission medications                                        39.0
# allergies                                                    59.0
# discharge condition                                          31.0
# discharge disposition                                         8.0
# physical examination                                         78.0
# date of birth                                                 0.0
# discharge medications                                        18.0
# social history                                               28.0
# discharge diagnosis                                          14.0
# family history                                               20.0
# discharge instructions                                       25.0
# attending                                                     0.0
# major surgical or invasive procedure                         16.0
# pertinent results                                            26.0
# followup instructions                                        32.0
# facility                                                      1.0
# completed by                                                  0.0
# dictated by                                                   0.0
# impression                                                    3.0
# discharge diagnoses                                           0.0
# department                                                    0.0
# findings                                                    393.0
# laboratory data                                               0.0
# review of systems                                             9.0
# provider                                                      0.0
# neurologic                                                   49.0
# ...                                                           ...
# micu admission vitals                                         0.0
# ct abdomen before and after iv contrast                       0.0
# micu course by problem list                                   0.0
# ct abd with iv and oral contrast                              0.0
# micu course notable for the following                         0.0
# micu events                                                   0.0
# micu events significant for                                   0.0
# micu hpi                                                      0.0
# micu imaging                                                  0.0
# micu labs                                                     0.0
# micu medications                                              0.0
# micu addend                                                   0.0
# ct abdomen upon admission read the following                  0.0
# microscopic hematuria                                         0.0
# ct and ctp of head                                            0.0
# microbiology at osh summary                                   0.0
# ct and mris                                                   0.0
# microbiology info                                             0.0
# microbiology labs                                             0.0
# microbiology on this admission                                0.0
# microbiology overview                                         0.0
# ct airways                                                    0.0
# microscopic                                                   0.0
# microbiology revealed the following                           0.0
# microbiology review                                           0.0
# ct abm                                                        0.0
# microbiololgy                                                 0.0
# microcalcifications                                           0.0
# ct abdomen with iv contrast and with limited or...            0.0
# zinc sulfate  220 mg capsule  sig                             0.0
#
#                                                     first_match  medication  \
# header_fixed
# service                                                  7739.0         0.0
# past medical history                                      348.0        77.0
# history of present illness                                380.0         3.0
# hospital course                                             5.0         0.0
# admission medications                                       0.0     47511.0
# allergies                                                   0.0         4.0
# discharge condition                                         3.0         0.0
# discharge disposition                                       1.0         0.0
# physical examination                                        3.0         0.0
# date of birth                                           46387.0         0.0
# discharge medications                                       0.0     45301.0
# social history                                              1.0         0.0
# discharge diagnosis                                         7.0         0.0
# family history                                              1.0         0.0
# discharge instructions                                      0.0         0.0
# attending                                                   1.0         0.0
# major surgical or invasive procedure                        0.0         0.0
# pertinent results                                           0.0         0.0
# followup instructions                                       0.0         0.0
# facility                                                    0.0         0.0
# completed by                                                0.0         0.0
# dictated by                                                 2.0         0.0
# impression                                                  1.0         0.0
# discharge diagnoses                                        18.0         0.0
# department                                                  0.0         0.0
# findings                                                    0.0         0.0
# laboratory data                                             0.0         0.0
# review of systems                                           0.0         0.0
# provider                                                    0.0         0.0
# neurologic                                                  0.0         0.0
# ...                                                         ...         ...
# micu admission vitals                                       0.0         1.0
# ct abdomen before and after iv contrast                     0.0         0.0
# micu course by problem list                                 0.0         0.0
# ct abd with iv and oral contrast                            0.0         0.0
# micu course notable for the following                       0.0         0.0
# micu events                                                 0.0         0.0
# micu events significant for                                 0.0         0.0
# micu hpi                                                    0.0         0.0
# micu imaging                                                0.0         0.0
# micu labs                                                   0.0         0.0
# micu medications                                            0.0         1.0
# micu addend                                                 0.0         0.0
# ct abdomen upon admission read the following                0.0         1.0
# microscopic hematuria                                       0.0         0.0
# ct and ctp of head                                          0.0         0.0
# microbiology at osh summary                                 0.0         0.0
# ct and mris                                                 0.0         0.0
# microbiology info                                           0.0         0.0
# microbiology labs                                           0.0         0.0
# microbiology on this admission                              0.0         1.0
# microbiology overview                                       0.0         0.0
# ct airways                                                  0.0         0.0
# microscopic                                                 0.0         0.0
# microbiology revealed the following                         0.0         0.0
# microbiology review                                         0.0         0.0
# ct abm                                                      0.0         0.0
# microbiololgy                                               0.0         0.0
# microcalcifications                                         0.0         0.0
# ct abdomen with iv contrast and with limited or...          0.0         0.0
# zinc sulfate  220 mg capsule  sig                           0.0         0.0
#
#                                                     multiline_section  row_id  \
# header_fixed
# service                                                        1949.0   53911
# past medical history                                          50061.0   51233
# history of present illness                                    49863.0   49891
# hospital course                                               48608.0   48722
# admission medications                                         46038.0   47511
# allergies                                                     40136.0   47254
# discharge condition                                           40840.0   47191
# discharge disposition                                         42524.0   46813
# physical examination                                          46483.0   46580
# date of birth                                                    33.0   46492
# discharge medications                                         45109.0   45301
# social history                                                43733.0   44448
# discharge diagnosis                                           41119.0   41324
# family history                                                39213.0   40759
# discharge instructions                                        38879.0   39012
# attending                                                     38421.0   38421
# major surgical or invasive procedure                          38229.0   38244
# pertinent results                                             37605.0   37629
# followup instructions                                         23780.0   37257
# facility                                                      24493.0   24494
# completed by                                                      0.0   20563
# dictated by                                                     657.0   16416
# impression                                                    12431.0   12755
# discharge diagnoses                                            7502.0    7592
# department                                                     4036.0    5988
# findings                                                       3411.0    3810
# laboratory data                                                3223.0    3260
# review of systems                                              2547.0    3024
# provider                                                       1914.0    2991
# neurologic                                                     2727.0    2955
# ...                                                               ...     ...
# micu admission vitals                                             1.0       1
# ct abdomen before and after iv contrast                           1.0       1
# micu course by problem list                                       1.0       1
# ct abd with iv and oral contrast                                  1.0       1
# micu course notable for the following                             1.0       1
# micu events                                                       1.0       1
# micu events significant for                                       1.0       1
# micu hpi                                                          1.0       1
# micu imaging                                                      1.0       1
# micu labs                                                         1.0       1
# micu medications                                                  1.0       1
# micu addend                                                       1.0       1
# ct abdomen upon admission read the following                      1.0       1
# microscopic hematuria                                             1.0       1
# ct and ctp of head                                                1.0       1
# microbiology at osh summary                                       1.0       1
# ct and mris                                                       1.0       1
# microbiology info                                                 1.0       1
# microbiology labs                                                 1.0       1
# microbiology on this admission                                    1.0       1
# microbiology overview                                             1.0       1
# ct airways                                                        1.0       1
# microscopic                                                       1.0       1
# microbiology revealed the following                               1.0       1
# microbiology review                                               1.0       1
# ct abm                                                            1.0       1
# microbiololgy                                                     1.0       1
# microcalcifications                                               1.0       1
# ct abdomen with iv contrast and with limited or...                1.0       1
# zinc sulfate  220 mg capsule  sig                                 1.0       1
#
#                                                     percentage
# header_fixed
# service                                              97.705566
# past medical history                                 92.852094
# history of present illness                           90.419921
# hospital course                                      88.301285
# admission medications                                86.106530
# allergies                                            85.640756
# discharge condition                                  85.526578
# discharge disposition                                84.841510
# physical examination                                 84.419233
# date of birth                                        84.259746
# discharge medications                                82.101238
# social history                                       80.555304
# discharge diagnosis                                  74.893524
# family history                                       73.869547
# discharge instructions                               70.703373
# attending                                            69.632274
# major surgical or invasive procedure                 69.311488
# pertinent results                                    68.196894
# followup instructions                                67.522700
# facility                                             44.391685
# completed by                                         37.267340
# dictated by                                          29.751527
# impression                                           23.116516
# discharge diagnoses                                  13.759356
# department                                           10.852348
# findings                                              6.905051
# laboratory data                                       5.908259
# review of systems                                     5.480544
# provider                                              5.420737
# neurologic                                            5.355492
# ...                                                        ...
# micu admission vitals                                 0.001812
# ct abdomen before and after iv contrast               0.001812
# micu course by problem list                           0.001812
# ct abd with iv and oral contrast                      0.001812
# micu course notable for the following                 0.001812
# micu events                                           0.001812
# micu events significant for                           0.001812
# micu hpi                                              0.001812
# micu imaging                                          0.001812
# micu labs                                             0.001812
# micu medications                                      0.001812
# micu addend                                           0.001812
# ct abdomen upon admission read the following          0.001812
# microscopic hematuria                                 0.001812
# ct and ctp of head                                    0.001812
# microbiology at osh summary                           0.001812
# ct and mris                                           0.001812
# microbiology info                                     0.001812
# microbiology labs                                     0.001812
# microbiology on this admission                        0.001812
# microbiology overview                                 0.001812
# ct airways                                            0.001812
# microscopic                                           0.001812
# microbiology revealed the following                   0.001812
# microbiology review                                   0.001812
# ct abm                                                0.001812
# microbiololgy                                         0.001812
# microcalcifications                                   0.001812
# ct abdomen with iv contrast and with limited or...    0.001812
# zinc sulfate  220 mg capsule  sig                     0.001812
#
# [13852 rows x 7 columns]

# %%
# notes which do not have this section
hdr_chk = 'admission medications'
not_these_row_id = sh.loc[sh['header_fixed']==hdr_chk, 'row_id']
ex_notes = sh.loc[ (~np.in1d(sh['row_id'], not_these_row_id)) , :]

display( HTML( ex_notes.head().to_html() ) )

# text of the first one
row_id = ex_notes['row_id'].unique()[5]
print('Note for row_id {}'.format(row_id))
print(df.loc[df['row_id']==row_id, 'text'].values[0])

# %%
# notes which have this section
hdr_chk = 'admission medications'
ex_notes = sh.loc[sh['header_fixed']==hdr_chk, :]
display( HTML( ex_notes.head().to_html() ) )

# text of a single note
row_id = ex_notes['row_id'].unique()[0]
print('Note for row_id {}'.format(row_id))
print(df.loc[df['row_id']==row_id, 'text'].values[0])
